# %%
print("HI")
# Out:
# HI

# %%
import pandas as pd

products = pd.read_csv("D:/Dare X AI/Data/products.csv")
outfits = pd.read_csv("D:/Dare X AI/Data/outfits.csv")

print(products.shape)
print(outfits.shape)
# Out:
# (68, 18)
# (25, 22)

# %%
outfits.columns.tolist()
# Out:
# ['outfit_id',
#  'gender',
#  'wear_type',
#  'occasion',
#  'theme',
#  'hero',
#  'hero_id',
#  'second',
#  'second_id',
#  'layer',
#  'layer_id',
#  'footwear',
#  'footwear_id',
#  'accessory_1',
#  'accessory_1_id',
#  'accessory_2',
#  'accessory_2_id',
#  'palette',
#  'items_count',
#  'total_price_inr',
#  'image_files',
#  'stylist_rationale']

# %%
products.columns.tolist()
# Out:
# ['id',
#  'name',
#  'brand',
#  'price_inr',
#  'rating',
#  'rating_count',
#  'gender',
#  'wear_type',
#  'category',
#  'category_label',
#  'occasion',
#  'tags',
#  'description',
#  'description_source',
#  'image',
#  'site',
#  'product_url',
#  'collected_at']

# %%
outfits.isnull().sum()
# Out:
# outfit_id             0
# gender                0
# wear_type             0
# occasion              0
# theme                 0
# hero                  0
# hero_id               0
# second               12
# second_id            12
# layer                21
# layer_id             21
# footwear              0
# footwear_id           0
# accessory_1           3
# accessory_1_id        3
# accessory_2          21
# accessory_2_id       21
# palette               0
# items_count           0
# total_price_inr       0
# image_files           0
# stylist_rationale     0
# dtype: int64

# %%
products.isnull().sum()
# Out:
# id                     0
# name                   0
# brand                  0
# price_inr              0
# rating                25
# rating_count          42
# gender                 0
# wear_type              0
# category               0
# category_label         0
# occasion               0
# tags                   0
# description            0
# description_source     0
# image                  0
# site                   0
# product_url            0
# collected_at           0
# dtype: int64

# %%
products["gender"].value_counts()
# Out:
# gender
# women    41
# men      27
# Name: count, dtype: int64

# %%
products["occasion"].value_counts()
# Out:
# occasion
# casual      15
# party       13
# office      12
# festive      9
# wedding      6
# sports       5
# vacation     4
# winter       4
# Name: count, dtype: int64

# %%
products["category"].value_counts().head(20)
# Out:
# category
# ethnic-footwear    4
# clutches           4
# heels              4
# party-dresses      3
# formal-shirts      3
# necklaces          2
# kurta-sets         2
# trousers           2
# handbags           2
# watches            2
# boots              2
# jeans              2
# formal-shoes       2
# sweatshirts        1
# track-pants        1
# party-shirts       1
# casual-shirts      1
# running-shoes      1
# sneakers           1
# sharara-sets       1
# Name: count, dtype: int64

# %%
outfits["occasion"].value_counts()
# Out:
# occasion
# party       6
# casual      5
# festive     4
# wedding     3
# office      2
# vacation    2
# sports      2
# winter      1
# Name: count, dtype: int64

# %%
outfits["wear_type"].value_counts()
# Out:
# wear_type
# western    19
# ethnic      6
# Name: count, dtype: int64
